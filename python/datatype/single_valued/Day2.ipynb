# %%
#integer datatype

a = 10
print(a)
# Out:
# 10

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
#default value for the integer
b  = int()
print(b) 

#type
print(type(b))
# Out:
# 0
# <class 'int'>

# %%
#float datatype

a = 3.45
print(a)
# Out:
# 3.45

# %%
a = 678.54
print(type(a))
# Out:
# <class 'float'>

# %%
#default value for the float

b = float()
print(b)

#type
print(type(b))
# Out:
# 0.0
# <class 'float'>

# %%
#complex

a = 3+5j
print(a)
# Out:
# (3+5j)

# %%
a = 5 + 3j
print(type(a))
# Out:
# <class 'complex'>

# %%
#default value for the complex

b = complex()
print(b)
# Out:
# 0j

# %%
#adding complex number

z1 = 4+5j
z2 = 5+6j

print(z1+z2)
# Out:
# (9+11j)

# %%
print(type(z1+z2))
# Out:
# <class 'complex'>

# %%
#boolean

a = True
print(a)
# Out:
# True

# %%
print(type(a))
# Out:
# <class 'bool'>

# %%
#default value for the bool

b = bool()
print(b)
# Out:
# False

# %%
c = 54
print(True == c)
# Out:
# False

# %%
d = 1

print(True == d)
# Out:
# True
