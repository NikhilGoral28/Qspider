# %%
#string

a = 'python'
print(a)
# Out:
# python

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
b = str()
print(b)

# %%
#string indexing
msg = 'education'

print(msg[1])
# Out:
# d

# %%
print(msg[5])
# Out:
# t

# %%
print(msg[-1])
# Out:
# n

# %%
print(msg[-2])
# Out:
# o

# %%
print(msg[8])
# Out:
# n

# %%
print(msg[10])  #string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(msg[10])
#
# IndexError: string index out of range

# %%
#string slicing

#positive slicing

string = 'Welcome to  python class'

# %%
print(string[0:7])
# Out:
# Welcome

# %%
print(string[8:10])
# Out:
# to

# %%
print(string[11:18])
# Out:
#  python

# %%
print(string[19:24])
# Out:
# class

# %%
print(string[0:10])
# Out:
# Welcome to

# %%
print(string[11:24])
# Out:
#  python class

# %%
print(string[])

# %%
print(string[3:10])
# Out:
# come to

# %%
print(string[5:16])
# Out:
# me to  pyth

# %%
print(string[:7])
# Out:
# Welcome

# %%
print(string[8:])
# Out:
# to  python class

# %%
#string slicing
#negative slicing

string = 'welcome to python class'

# %%
print(string[-5:])
# Out:
# class

# %%
print(string[-12:-6])
# Out:
# python

# %%
print(string[-23:-16])
# Out:
# welcome

# %%
print(string[-15:-13])
# Out:
# to

# %%
print(string[-11:-7])
# Out:
# ytho

# %%
print(string[-23:-1])
# Out:
# welcome to python clas

# %%
print(string[:-6])
# Out:
# welcome to python

# %%
print(string[-6:])
# Out:
#  class

# %%
print(string[-10:-5])
# Out:
# thon

# %%
#reversing

print(string[::-1])
# Out:
# ssalc nohtyp ot emoclew

# %%
print(string[22::-1])
# Out:
# ssalc nohtyp ot emoclew

# %%
print(string[16:10:-1])
# Out:
# nohtyp

# %%
print(string[-1:-6:-1])
# Out:
# ssalc

# %%
print(string[9::-1])
# Out:
# ot emoclew
