# %%
x,y = 1,1
def f():
    print(x,y)
    y = 2

f()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3     print(x,y)
#       4     y = 2
# ----> 6 f()
#
# Cell In[1], line 3, in f()
#       2 def f():
# ----> 3     print(x,y)
#       4     y = 2
#
# UnboundLocalError: cannot access local variable 'y' where it is not associated with a value

# %%
import numpy as np
